# %% [markdown]
# TASK-1

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Size'] = le.fit_transform(df['Size'])
df = pd.get_dummies(df,columns=['City'])
print(df)
# Out:
#    Gender  Size  Age  Fare  City_Chennai  City_Delhi  City_Mumbai
# 0       1     2   25    15         False       False         True
# 1       0     0   45   300         False        True        False
# 2       0     1   32    85          True       False        False
# 3       1     0   60   450         False       False         True
# 4       0     2   28    20         False        True        False

# %% [markdown]
# TASK-2

# %%
# from numpy import std
# age_mean = df['Age'].mean()
# fare_median = df['Fare'].median()
# age_std = df['Age'].std()
# q1 = df['Fare'].quantile(0.25)
# q3 = df['Fare'].quantile(0.75)
# fare_iqr = q3-q1
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
std_sclr = StandardScaler()
rob_sclr = RobustScaler()
df['Age_scaling'] = std_sclr.fit_transform(df[['Age']])
df['Fare_scaling'] = rob_sclr.fit_transform(df[['Fare']])
print(f"Age-before: {df['Age']}")
print(f"Age-after: {df['Age_scaling']}")
print(f"Fare before: {df['Fare']}")
print(f"Fare after: {df['Fare_scaling']}")
# Out:
# Age-before: 0    25
# 1    45
# 2    32
# 3    60
# 4    28
# Name: Age, dtype: int64
# Age-after: 0   -1.004168
# 1    0.540706
# 2   -0.463462
# 3    1.699361
# 4   -0.772437
# Name: Age_scaling, dtype: float64
# Fare before: 0     15
# 1    300
# 2     85
# 3    450
# 4     20
# Name: Fare, dtype: int64
# Fare after: 0   -0.250000
# 1    0.767857
# 2    0.000000
# 3    1.303571
# 4   -0.232143
# Name: Fare_scaling, dtype: float64
